# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 데이터셋 불러오기
df=pd.read_csv('/Users/bluecloud/Documents/대학/유런/데이터셋/cleand_jobs.csv')
df.head(10)
# Out:
#                   job_category  salary_in_usd experience_level  \
# 0                Data Analysis          95000      Entry-level
# 1                Data Analysis          75000      Entry-level
# 2    Data Science and Research          72000      Entry-level
# 3    Data Science and Research          64000      Entry-level
# 4                Data Analysis         100000      Entry-level
# 5                Data Analysis          75000      Entry-level
# 6  Data Quality and Operations          49216      Entry-level
# 7  Data Quality and Operations          36912      Entry-level
# 8                Data Analysis         105000      Entry-level
# 9      Machine Learning and AI         133000      Entry-level
#
#   employment_type work_setting company_location company_size  job_group
# 0       Full-time    In-person    United States            M          0
# 1       Full-time    In-person    United States            M          0
# 2       Full-time       Remote    United States            M          2
# 3       Full-time       Remote    United States            M          2
# 4       Full-time    In-person    United States            M          0
# 5       Full-time    In-person    United States            M          0
# 6       Full-time       Remote   United Kingdom            M          1
# 7       Full-time       Remote   United Kingdom            M          1
# 8       Full-time    In-person    United States            M          0
# 9       Full-time    In-person    United States            M          2
